# %% [markdown]
# # **!!!!非常重要!!!!**
# ### **請先在自己的Google drive建立 Aidea_data 這個名字的資料夾**
# ### **將所有hdf5檔和ckpt檔移到 Aidea_data 這個資料夾**
# Aidea_data裡面包刮所有的hdf5格式的train data, valid data, test data還有一些checkpoint檔案(ckpt檔)
#
# 所有hdf5資料和所有ckpt檔下載路徑, 把這些hdf5資料和ckpt檔下載下來移到自己google drive所建立的 Aidea_data 資料夾裡面
#
# 確認自己的Aidea_data路徑為 : '/content/drive/MyDrive/Aidea_data'
#
# https://drive.google.com/drive/folders/1WIwse2gGgs5t0CkjYdztatfQFpvR0WMf?usp=sharing

# %% [markdown]
# # **Mount google drive**

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Aidea_data')
# !ls
# Out:
# Mounted at /content/drive
# banana_train.hdf5
# banana_valid.hdf5
# bareland_train.hdf5
# bareland_valid.hdf5
# carrot_train.hdf5
# carrot_valid.hdf5
# corn_train.hdf5
# corn_valid.hdf5
# dragonfruit_train.hdf5
# dragonfruit_valid.hdf5
# garlic_train.hdf5
# garlic_valid.hdf5
# guava_train.hdf5
# guava_valid.hdf5
# peanut_train.hdf5
# peanut_valid.hdf5
# pineapple_train.hdf5
# pineapple_valid.hdf5
# pumpkin_train.hdf5
# pumpkin_valid.hdf5
# rice_train.hdf5
# rice_valid.hdf5
# sample_3_Eff_b4_lrsche_imbalance_imbalance_best.ckpt
# sample_kk_Effb3_imbalance_best.ckpt
# sample_once_kk_Effb6_imbalance_best.ckpt
# soybean_train.hdf5
# soybean_valid.hdf5
# sugarcane_train.hdf5
# sugarcane_valid.hdf5
# test_0.hdf5
# test_1.hdf5
# test_2.hdf5
# test_3.hdf5
# test_4.hdf5
# test_5.hdf5
# test_6.hdf5
# test_7.hdf5
# test_8.hdf5
# test_9.hdf5
# test_a.hdf5
# test_b.hdf5
# test_c.hdf5
# test_d.hdf5
# test_e.hdf5
# test_f.hdf5
# tomato_train.hdf5
# tomato_valid.hdf5

# %% [markdown]
# # **Check GPU type**

# %%
# !nvidia-smi
# Out:
# Fri May 20 04:54:00 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # **Parameters settings**
# ### 三個我的訓練參數load路徑
# ##### For EffNet b3 model_2: "/content/drive/MyDrive/Aidea_data/sample_kk_Effb3_imbalance_best.ckpt"
# ##### For EffNet b4 model_3: "/content/drive/MyDrive/Aidea_data/sample_3_Eff_b4_lrsche_imbalance_imbalancee_best.ckpt"
# ##### For EffNet b6 model_4: "/content/drive/MyDrive/Aidea_data/sample_once_kk_Effb6_imbalance_best.ckpt"

# %%
num_class = 14
batch_size = 16 
#----------------------------------------------------------------------------------------------------------------------------------------------
# Setting checkpoint path you have trained
#_exp_name_model_1 = "sample_EffNetb3"
_exp_name_model_2 = "sample_kk_Effb3_imbalance"
_exp_name_model_3 = "sample_3_Eff_b4_lrsche_imbalance_imbalance"
_exp_name_model_4 = "sample_once_kk_Effb6_imbalance"
#_exp_name_model_5 = "sample_kk_Effb3_imbalance"

#checkpoint1_path = "/content/drive/MyDrive/Aidea_data/"+_exp_name_model_1+"_"+"best.ckpt"
checkpoint2_path = "/content/drive/MyDrive/Aidea_data/"+_exp_name_model_2+"_"+"best.ckpt"
checkpoint3_path = "/content/drive/MyDrive/Aidea_data/"+_exp_name_model_3+"_"+"best.ckpt"
checkpoint4_path = "/content/drive/MyDrive/Aidea_data/"+_exp_name_model_4+"_"+"best.ckpt"
#checkpoint5_path = "/content/drive/MyDrive/Aidea_data/"+_exp_name_model_5+"_"+"best.ckpt"
#----------------------------------------------------------------------------------------------------------------------------------------------
# Setting the number of ensemble model : weight number
weight_num = 3
#lam1 = 1/weight_num
lam2 = 1/weight_num
lam3 = 1/weight_num
lam4 = 1/weight_num
#lam5 = 1/weight_num
#-----------------------------------------------------------------------------------------------------------------------------------------------
# Setting the TTA weight : alpha
TTA_w = 7
TTA_coe = 0.965
w_test = TTA_coe
w_train1 = (1-TTA_coe)/TTA_w
w_train2 = (1-TTA_coe)/TTA_w
w_train3 = (1-TTA_coe)/TTA_w
w_train4 = (1-TTA_coe)/TTA_w
w_train5 = (1-TTA_coe)/TTA_w
w_train6 = (1-TTA_coe)/TTA_w
w_train7 = (1-TTA_coe)/TTA_w
#w_train8 = (1-TTA_coe)/TTA_w
#w_train9 = (1-TTA_coe)/TTA_w
#w_train10 = (1-TTA_coe)/TTA_w

# %% [markdown]
# # **Copy the file from google drive into local destination**

# %%
# !cp -r /content/drive/MyDrive/Aidea_data/test_0.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_1.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_2.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_3.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_4.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_5.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_6.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_7.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_8.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_9.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_a.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_b.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_c.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_d.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_e.hdf5 /content
# !cp -r /content/drive/MyDrive/Aidea_data/test_f.hdf5 /content

# %% [markdown]
# # **Import Package**

# %%
# Import necessary packages.
import numpy as np
import torch
import os
import torch.nn as nn
import torchvision.transforms as transforms
from PIL import Image
# "ConcatDataset" and "Subset" are possibly useful when doing semi-supervised learning.
from torch.utils.data import ConcatDataset, DataLoader, Subset, Dataset
from torchvision.datasets import DatasetFolder, VisionDataset
from numpy.ma.core import true_divide

import pandas as pd

# This is for the progress bar.
from tqdm.auto import tqdm
import random

# For dataset organization:
import os
import shutil
from shutil import copy2, move


import h5py
import numpy as np
import os
import matplotlib.pyplot as plt
import io
from PIL import Image

import torchvision.models as models
import torch.nn as nn
import torch
import time
import copy
from torch.optim import lr_scheduler

# %% [markdown]
# # **Envrionment Settings**

# %%
from numpy.ma.core import true_divide
myseed = 6666  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# # **TTA Data augmentation**

# %%
# Normally, We don't need augmentations in testing and validation.
# All we need here is to resize the PIL image and transform it into Tensor.
test_tfm = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])


# However, it is also possible to use augmentation in the testing phase.
# You may use train_tfm to produce a variety of images and then test using ensemble methods
train_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    # You may add some transforms here.
    transforms.RandomRotation(40),
    transforms.RandomAffine(degrees=0, translate=(0.2, 0.2), shear=0.2),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.Resize((224, 224)),
    transforms.GaussianBlur(3,sigma=(0.1, 2.0)),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train2_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    # You may add some transforms here.
    transforms.RandomRotation(40),
    #transforms.RandomAffine(degrees=0, translate=(0.2, 0.2), shear=0.2),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.Resize((224, 224)),
    #transforms.GaussianBlur(3,sigma=(0.1, 2.0)),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train3_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    # You may add some transforms here.
    #transforms.RandomRotation(40),
    #transforms.RandomAffine(degrees=0, translate=(0.2, 0.2), shear=0.2),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.Resize((224, 224)),
    transforms.GaussianBlur(3,sigma=(0.1, 2.0)),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train4_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    # You may add some transforms here.
    #transforms.RandomRotation(40),
    transforms.RandomAffine(degrees=0, translate=(0.2, 0.2), shear=0.2),
    #transforms.RandomHorizontalFlip(p=0.5),
    transforms.Resize((224, 224)),
    transforms.GaussianBlur(3,sigma=(0.1, 2.0)),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train5_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    # You may add some transforms here.
    #transforms.RandomRotation(40),
    #transforms.RandomAffine(degrees=0, translate=(0.2, 0.2), shear=0.2),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.Resize((224, 224)),
    transforms.GaussianBlur(3,sigma=(0.1, 2.0)),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train6_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    # You may add some transforms here.
    #transforms.RandomRotation(40),
    #transforms.RandomAffine(degrees=0, translate=(0.2, 0.2), shear=0.2),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.Resize((224, 224)),
    #transforms.GaussianBlur(3,sigma=(0.1, 2.0)),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train7_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    # You may add some transforms here.
    #transforms.RandomRotation(40),
    #transforms.RandomAffine(degrees=0, translate=(0.2, 0.2), shear=0.2),
    #transforms.RandomHorizontalFlip(p=0.5),
    transforms.Resize((224, 224)),
    transforms.GaussianBlur(3,sigma=(0.1, 2.0)),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
'''
train8_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    # You may add some transforms here.
    #transforms.RandomRotation(40),
    transforms.RandomAffine(degrees=0, translate=(0.2, 0.2), shear=0.2),
    #transforms.RandomHorizontalFlip(p=0.5),
    transforms.Resize((224, 224)),
    #transforms.GaussianBlur(3,sigma=(0.1, 2.0)),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train9_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    # You may add some transforms here.
    transforms.RandomRotation(40),
    #transforms.RandomAffine(degrees=0, translate=(0.2, 0.2), shear=0.2),
    #transforms.RandomHorizontalFlip(p=0.5),
    transforms.Resize((224, 224)),
    #transforms.GaussianBlur(3,sigma=(0.1, 2.0)),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train10_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    # You may add some transforms here.
    #transforms.RandomRotation(40),
    transforms.RandomAffine(degrees=0, translate=(0.2, 0.2), shear=0.2),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.Resize((224, 224)),
    #transforms.GaussianBlur(3,sigma=(0.1, 2.0)),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
'''
# Out:
# '\ntrain8_tfm = transforms.Compose([\n    # Resize the image into a fixed shape (height = width = 128)\n    # You may add some transforms here.\n    #transforms.RandomRotation(40),\n    transforms.RandomAffine(degrees=0, translate=(0.2, 0.2), shear=0.2),\n    #transforms.RandomHorizontalFlip(p=0.5),\n    transforms.Resize((224, 224)),\n    #transforms.GaussianBlur(3,sigma=(0.1, 2.0)),\n    # ToTensor() should be the last one of the transforms.\n    transforms.ToTensor(),\n    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])\n])\n\ntrain9_tfm = transforms.Compose([\n    # Resize the image into a fixed shape (height = width = 128)\n    # You may add some transforms here.\n    transforms.RandomRotation(40),\n    #transforms.RandomAffine(degrees=0, translate=(0.2, 0.2), shear=0.2),\n    #transforms.RandomHorizontalFlip(p=0.5),\n    transforms.Resize((224, 224)),\n    #transforms.GaussianBlur(3,sigma=(0.1, 2.0)),\n    # ToTensor() should be the last one of the transforms
# ...

# %% [markdown]
# # **Test Dataset Preparing**

# %%
test_0_Dir = "/content/test_0.hdf5"
test_1_Dir = "/content/test_1.hdf5"
test_2_Dir = "/content/test_2.hdf5"
test_3_Dir = "/content/test_3.hdf5"
test_4_Dir = "/content/test_4.hdf5"
test_5_Dir = "/content/test_5.hdf5"
test_6_Dir = "/content/test_6.hdf5"
test_7_Dir = "/content/test_7.hdf5"
test_8_Dir = "/content/test_8.hdf5"
test_9_Dir = "/content/test_9.hdf5"
test_a_Dir = "/content/test_a.hdf5"
test_b_Dir = "/content/test_b.hdf5"
test_c_Dir = "/content/test_c.hdf5"
test_d_Dir = "/content/test_d.hdf5"
test_e_Dir = "/content/test_e.hdf5"
test_f_Dir = "/content/test_f.hdf5"

# %%
class AIDEA_Dataset(Dataset):

    def __init__(self,path,tfm=test_tfm,types=None,files = None, file_name=True):
        super(AIDEA_Dataset).__init__()
        self.path = path
        self.hf = h5py.File(path, 'r')
        self.files = list(h5py.File(path, 'r').keys())
        #self.files = sorted([os.path.join(path,x) for x in os.listdir(path) if x.endswith(".JPG")])
        if files != None:
            self.files = files
        self.transform = tfm
        self.types = types
        self.file_name = file_name
  
    def __len__(self):
        return len(self.files)
  
    def __getitem__(self,idx):
        fname = self.files[idx]
        data = np.array(self.hf[fname])
        im = Image.open(io.BytesIO(data))
        im = self.transform(im)
        if self.types =="banana":
            label = 0
        elif self.types =="bareland":
            label = 1
        elif self.types =="carrot":
            label = 2
        elif self.types =="corn":
            label = 3
        elif self.types =="dragonfruit":
            label = 4
        elif self.types =="garlic":
            label = 5
        elif self.types =="guava":
            label = 6
        elif self.types =="peanut":
            label = 7
        elif self.types =="pineapple":
            label = 8
        elif self.types =="pumpkin":
            label = 9
        elif self.types =="rice":
            label = 10
        elif self.types =="soybean":
            label = 11
        elif self.types =="sugarcane":
            label = 12
        elif self.types =="tomato":
            label = 13
        else:
            label = -1

        if self.file_name:
          return im,label,fname
        else:
          return im,label

# %% [markdown]
# ### TTA : for various train data augmentation

# %%
Train1_testset_0 = AIDEA_Dataset(test_0_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_1 = AIDEA_Dataset(test_1_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_2 = AIDEA_Dataset(test_2_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_3 = AIDEA_Dataset(test_3_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_4 = AIDEA_Dataset(test_4_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_5 = AIDEA_Dataset(test_5_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_6 = AIDEA_Dataset(test_6_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_7 = AIDEA_Dataset(test_7_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_8 = AIDEA_Dataset(test_8_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_9 = AIDEA_Dataset(test_9_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_a = AIDEA_Dataset(test_a_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_b = AIDEA_Dataset(test_b_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_c = AIDEA_Dataset(test_c_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_d = AIDEA_Dataset(test_d_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_e = AIDEA_Dataset(test_e_Dir, tfm=train_tfm, types=None,file_name=True)
Train1_testset_f = AIDEA_Dataset(test_f_Dir, tfm=train_tfm, types=None,file_name=True)

Train2_testset_0 = AIDEA_Dataset(test_0_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_1 = AIDEA_Dataset(test_1_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_2 = AIDEA_Dataset(test_2_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_3 = AIDEA_Dataset(test_3_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_4 = AIDEA_Dataset(test_4_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_5 = AIDEA_Dataset(test_5_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_6 = AIDEA_Dataset(test_6_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_7 = AIDEA_Dataset(test_7_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_8 = AIDEA_Dataset(test_8_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_9 = AIDEA_Dataset(test_9_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_a = AIDEA_Dataset(test_a_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_b = AIDEA_Dataset(test_b_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_c = AIDEA_Dataset(test_c_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_d = AIDEA_Dataset(test_d_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_e = AIDEA_Dataset(test_e_Dir, tfm=train2_tfm, types=None,file_name=True)
Train2_testset_f = AIDEA_Dataset(test_f_Dir, tfm=train2_tfm, types=None,file_name=True)

Train3_testset_0 = AIDEA_Dataset(test_0_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_1 = AIDEA_Dataset(test_1_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_2 = AIDEA_Dataset(test_2_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_3 = AIDEA_Dataset(test_3_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_4 = AIDEA_Dataset(test_4_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_5 = AIDEA_Dataset(test_5_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_6 = AIDEA_Dataset(test_6_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_7 = AIDEA_Dataset(test_7_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_8 = AIDEA_Dataset(test_8_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_9 = AIDEA_Dataset(test_9_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_a = AIDEA_Dataset(test_a_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_b = AIDEA_Dataset(test_b_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_c = AIDEA_Dataset(test_c_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_d = AIDEA_Dataset(test_d_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_e = AIDEA_Dataset(test_e_Dir, tfm=train3_tfm, types=None,file_name=True)
Train3_testset_f = AIDEA_Dataset(test_f_Dir, tfm=train3_tfm, types=None,file_name=True)

Train4_testset_0 = AIDEA_Dataset(test_0_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_1 = AIDEA_Dataset(test_1_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_2 = AIDEA_Dataset(test_2_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_3 = AIDEA_Dataset(test_3_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_4 = AIDEA_Dataset(test_4_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_5 = AIDEA_Dataset(test_5_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_6 = AIDEA_Dataset(test_6_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_7 = AIDEA_Dataset(test_7_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_8 = AIDEA_Dataset(test_8_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_9 = AIDEA_Dataset(test_9_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_a = AIDEA_Dataset(test_a_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_b = AIDEA_Dataset(test_b_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_c = AIDEA_Dataset(test_c_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_d = AIDEA_Dataset(test_d_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_e = AIDEA_Dataset(test_e_Dir, tfm=train4_tfm, types=None,file_name=True)
Train4_testset_f = AIDEA_Dataset(test_f_Dir, tfm=train4_tfm, types=None,file_name=True)

Train5_testset_0 = AIDEA_Dataset(test_0_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_1 = AIDEA_Dataset(test_1_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_2 = AIDEA_Dataset(test_2_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_3 = AIDEA_Dataset(test_3_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_4 = AIDEA_Dataset(test_4_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_5 = AIDEA_Dataset(test_5_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_6 = AIDEA_Dataset(test_6_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_7 = AIDEA_Dataset(test_7_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_8 = AIDEA_Dataset(test_8_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_9 = AIDEA_Dataset(test_9_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_a = AIDEA_Dataset(test_a_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_b = AIDEA_Dataset(test_b_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_c = AIDEA_Dataset(test_c_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_d = AIDEA_Dataset(test_d_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_e = AIDEA_Dataset(test_e_Dir, tfm=train5_tfm, types=None,file_name=True)
Train5_testset_f = AIDEA_Dataset(test_f_Dir, tfm=train5_tfm, types=None,file_name=True)

Train6_testset_0 = AIDEA_Dataset(test_0_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_1 = AIDEA_Dataset(test_1_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_2 = AIDEA_Dataset(test_2_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_3 = AIDEA_Dataset(test_3_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_4 = AIDEA_Dataset(test_4_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_5 = AIDEA_Dataset(test_5_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_6 = AIDEA_Dataset(test_6_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_7 = AIDEA_Dataset(test_7_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_8 = AIDEA_Dataset(test_8_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_9 = AIDEA_Dataset(test_9_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_a = AIDEA_Dataset(test_a_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_b = AIDEA_Dataset(test_b_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_c = AIDEA_Dataset(test_c_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_d = AIDEA_Dataset(test_d_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_e = AIDEA_Dataset(test_e_Dir, tfm=train6_tfm, types=None,file_name=True)
Train6_testset_f = AIDEA_Dataset(test_f_Dir, tfm=train6_tfm, types=None,file_name=True)

Train7_testset_0 = AIDEA_Dataset(test_0_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_1 = AIDEA_Dataset(test_1_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_2 = AIDEA_Dataset(test_2_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_3 = AIDEA_Dataset(test_3_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_4 = AIDEA_Dataset(test_4_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_5 = AIDEA_Dataset(test_5_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_6 = AIDEA_Dataset(test_6_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_7 = AIDEA_Dataset(test_7_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_8 = AIDEA_Dataset(test_8_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_9 = AIDEA_Dataset(test_9_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_a = AIDEA_Dataset(test_a_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_b = AIDEA_Dataset(test_b_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_c = AIDEA_Dataset(test_c_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_d = AIDEA_Dataset(test_d_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_e = AIDEA_Dataset(test_e_Dir, tfm=train7_tfm, types=None,file_name=True)
Train7_testset_f = AIDEA_Dataset(test_f_Dir, tfm=train7_tfm, types=None,file_name=True)
'''
Train8_testset_0 = AIDEA_Dataset(test_0_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_1 = AIDEA_Dataset(test_1_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_2 = AIDEA_Dataset(test_2_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_3 = AIDEA_Dataset(test_3_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_4 = AIDEA_Dataset(test_4_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_5 = AIDEA_Dataset(test_5_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_6 = AIDEA_Dataset(test_6_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_7 = AIDEA_Dataset(test_7_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_8 = AIDEA_Dataset(test_8_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_9 = AIDEA_Dataset(test_9_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_a = AIDEA_Dataset(test_a_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_b = AIDEA_Dataset(test_b_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_c = AIDEA_Dataset(test_c_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_d = AIDEA_Dataset(test_d_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_e = AIDEA_Dataset(test_e_Dir, tfm=train8_tfm, types=None,file_name=True)
Train8_testset_f = AIDEA_Dataset(test_f_Dir, tfm=train8_tfm, types=None,file_name=True)

Train9_testset_0 = AIDEA_Dataset(test_0_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_1 = AIDEA_Dataset(test_1_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_2 = AIDEA_Dataset(test_2_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_3 = AIDEA_Dataset(test_3_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_4 = AIDEA_Dataset(test_4_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_5 = AIDEA_Dataset(test_5_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_6 = AIDEA_Dataset(test_6_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_7 = AIDEA_Dataset(test_7_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_8 = AIDEA_Dataset(test_8_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_9 = AIDEA_Dataset(test_9_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_a = AIDEA_Dataset(test_a_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_b = AIDEA_Dataset(test_b_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_c = AIDEA_Dataset(test_c_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_d = AIDEA_Dataset(test_d_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_e = AIDEA_Dataset(test_e_Dir, tfm=train9_tfm, types=None,file_name=True)
Train9_testset_f = AIDEA_Dataset(test_f_Dir, tfm=train9_tfm, types=None,file_name=True)

Train10_testset_0 = AIDEA_Dataset(test_0_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_1 = AIDEA_Dataset(test_1_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_2 = AIDEA_Dataset(test_2_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_3 = AIDEA_Dataset(test_3_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_4 = AIDEA_Dataset(test_4_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_5 = AIDEA_Dataset(test_5_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_6 = AIDEA_Dataset(test_6_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_7 = AIDEA_Dataset(test_7_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_8 = AIDEA_Dataset(test_8_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_9 = AIDEA_Dataset(test_9_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_a = AIDEA_Dataset(test_a_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_b = AIDEA_Dataset(test_b_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_c = AIDEA_Dataset(test_c_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_d = AIDEA_Dataset(test_d_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_e = AIDEA_Dataset(test_e_Dir, tfm=train10_tfm, types=None,file_name=True)
Train10_testset_f = AIDEA_Dataset(test_f_Dir, tfm=train10_tfm, types=None,file_name=True)
'''
Train1_testset_con = ConcatDataset([Train1_testset_0, Train1_testset_1, Train1_testset_2, Train1_testset_3, Train1_testset_4, Train1_testset_5,\
                Train1_testset_6, Train1_testset_7,  Train1_testset_8, Train1_testset_9, Train1_testset_a, Train1_testset_b,\
                Train1_testset_c, Train1_testset_d, Train1_testset_e, Train1_testset_f])
Train2_testset_con = ConcatDataset([Train2_testset_0, Train2_testset_1, Train2_testset_2, Train2_testset_3, Train2_testset_4, Train2_testset_5,\
                Train2_testset_6, Train2_testset_7,  Train2_testset_8, Train2_testset_9, Train2_testset_a, Train2_testset_b,\
                Train2_testset_c, Train2_testset_d, Train2_testset_e, Train2_testset_f])

Train3_testset_con = ConcatDataset([Train3_testset_0, Train3_testset_1, Train3_testset_2, Train3_testset_3, Train3_testset_4, Train3_testset_5,\
                Train3_testset_6, Train3_testset_7,  Train3_testset_8, Train3_testset_9, Train3_testset_a, Train3_testset_b,\
                Train3_testset_c, Train3_testset_d, Train3_testset_e, Train3_testset_f])

Train4_testset_con = ConcatDataset([Train4_testset_0, Train4_testset_1, Train4_testset_2, Train4_testset_3, Train4_testset_4, Train4_testset_5,\
                Train4_testset_6, Train4_testset_7,  Train4_testset_8, Train4_testset_9, Train4_testset_a, Train4_testset_b,\
                Train4_testset_c, Train4_testset_d, Train4_testset_e, Train4_testset_f])

Train5_testset_con = ConcatDataset([Train5_testset_0, Train5_testset_1, Train5_testset_2, Train5_testset_3, Train5_testset_4, Train5_testset_5,\
                Train5_testset_6, Train5_testset_7,  Train5_testset_8, Train5_testset_9, Train5_testset_a, Train5_testset_b,\
                Train5_testset_c, Train5_testset_d, Train5_testset_e, Train5_testset_f])

Train6_testset_con = ConcatDataset([Train6_testset_0, Train6_testset_1, Train6_testset_2, Train6_testset_3, Train6_testset_4, Train6_testset_5,\
                Train6_testset_6, Train6_testset_7,  Train6_testset_8, Train6_testset_9, Train6_testset_a, Train6_testset_b,\
                Train6_testset_c, Train6_testset_d, Train6_testset_e, Train6_testset_f])

Train7_testset_con = ConcatDataset([Train7_testset_0, Train7_testset_1, Train7_testset_2, Train7_testset_3, Train7_testset_4, Train7_testset_5,\
                Train7_testset_6, Train7_testset_7,  Train7_testset_8, Train7_testset_9, Train7_testset_a, Train7_testset_b,\
                Train7_testset_c, Train7_testset_d, Train7_testset_e, Train7_testset_f])
'''
Train8_testset_con = ConcatDataset([Train8_testset_0, Train8_testset_1, Train8_testset_2, Train8_testset_3, Train8_testset_4, Train8_testset_5,\
                Train8_testset_6, Train8_testset_7,  Train8_testset_8, Train8_testset_9, Train8_testset_a, Train8_testset_b,\
                Train8_testset_c, Train8_testset_d, Train8_testset_e, Train8_testset_f])

Train9_testset_con = ConcatDataset([Train9_testset_0, Train9_testset_1, Train9_testset_2, Train9_testset_3, Train9_testset_4, Train9_testset_5,\
                Train9_testset_6, Train9_testset_7,  Train9_testset_8, Train9_testset_9, Train9_testset_a, Train9_testset_b,\
                Train9_testset_c, Train9_testset_d, Train9_testset_e, Train9_testset_f])

Train10_testset_con = ConcatDataset([Train10_testset_0, Train10_testset_1, Train10_testset_2, Train10_testset_3, Train10_testset_4, Train10_testset_5,\
                Train10_testset_6, Train10_testset_7,  Train10_testset_8, Train10_testset_9, Train10_testset_a, Train10_testset_b,\
                Train10_testset_c, Train10_testset_d, Train10_testset_e, Train10_testset_f])
'''
Train1_test_loader = DataLoader(Train1_testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
Train2_test_loader = DataLoader(Train2_testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
Train3_test_loader = DataLoader(Train3_testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
Train4_test_loader = DataLoader(Train4_testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
Train5_test_loader = DataLoader(Train5_testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
Train6_test_loader = DataLoader(Train6_testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
Train7_test_loader = DataLoader(Train7_testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
'''
Train8_test_loader = DataLoader(Train8_testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
Train9_test_loader = DataLoader(Train9_testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
Train10_test_loader = DataLoader(Train10_testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
'''
# Out:
# '\nTrain8_test_loader = DataLoader(Train8_testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)\nTrain9_test_loader = DataLoader(Train9_testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)\nTrain10_test_loader = DataLoader(Train10_testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)\n'

# %% [markdown]
# ### Test dataloader

# %%
# Concat all test data and total number of test data is about 20,000:
testset_0 = AIDEA_Dataset(test_0_Dir, tfm=test_tfm, types=None,file_name=True)
testset_1 = AIDEA_Dataset(test_1_Dir, tfm=test_tfm, types=None,file_name=True)
testset_2 = AIDEA_Dataset(test_2_Dir, tfm=test_tfm, types=None,file_name=True)
testset_3 = AIDEA_Dataset(test_3_Dir, tfm=test_tfm, types=None,file_name=True)
testset_4 = AIDEA_Dataset(test_4_Dir, tfm=test_tfm, types=None,file_name=True)
testset_5 = AIDEA_Dataset(test_5_Dir, tfm=test_tfm, types=None,file_name=True)
testset_6 = AIDEA_Dataset(test_6_Dir, tfm=test_tfm, types=None,file_name=True)
testset_7 = AIDEA_Dataset(test_7_Dir, tfm=test_tfm, types=None,file_name=True)
testset_8 = AIDEA_Dataset(test_8_Dir, tfm=test_tfm, types=None,file_name=True)
testset_9 = AIDEA_Dataset(test_9_Dir, tfm=test_tfm, types=None,file_name=True)
testset_a = AIDEA_Dataset(test_a_Dir, tfm=test_tfm, types=None,file_name=True)
testset_b = AIDEA_Dataset(test_b_Dir, tfm=test_tfm, types=None,file_name=True)
testset_c = AIDEA_Dataset(test_c_Dir, tfm=test_tfm, types=None,file_name=True)
testset_d = AIDEA_Dataset(test_d_Dir, tfm=test_tfm, types=None,file_name=True)
testset_e = AIDEA_Dataset(test_e_Dir, tfm=test_tfm, types=None,file_name=True)
testset_f = AIDEA_Dataset(test_f_Dir, tfm=test_tfm, types=None,file_name=True)

testset_con = ConcatDataset([testset_0, testset_1, testset_2, testset_3, testset_4, testset_5, testset_6,\
                testset_7, testset_8,  testset_9, testset_a, testset_b, testset_c,\
                testset_d, testset_e, testset_f])
print("Length of test data is ", len(testset_con))

test_loader = DataLoader(testset_con, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
# Out:
# Length of test data is  20000

# %% [markdown]
# # **Evaluate : TTA+Ensemble**

# %%
class focal_loss(nn.Module):
  def __init__(self, gamma=2):
    super(focal_loss, self).__init__()
    self.gamma = gamma
    self.ce = nn.CrossEntropyLoss()
  def forward(self, input, label):
    logp = self.ce(input, label)
    p = torch.exp(-logp)
    loss = (1-p)**self.gamma * logp
    return loss.mean()

'''
model1 = models.efficientnet_b3(pretrained=True)
num_ftrs1 = model1.classifier[1].in_features
model1.classifier[1] = nn.Linear(num_ftrs1, num_class)
checkpoint1 = torch.load(checkpoint1_path) # for effnetb3 aug
model1.load_state_dict(checkpoint1['model_state_dict'])
model1 = model1.to(device)
'''
model2 = models.efficientnet_b3(pretrained=True)
num_ftrs2 = model2.classifier[1].in_features
model2.classifier[1] = nn.Linear(num_ftrs2, num_class)
checkpoint2 = torch.load(checkpoint2_path) # for effnetb3, imbalance
model2.load_state_dict(checkpoint2['model_state_dict'])
model2 = model2.to(device)

model3 = models.efficientnet_b4(pretrained=True)
num_ftrs3 = model3.classifier[1].in_features
model3.classifier[1] = nn.Linear(num_ftrs3, num_class)
checkpoint3 = torch.load(checkpoint3_path) # for effnetb4, imbalance
model3.load_state_dict(checkpoint3['model_state_dict'])
model3 = model3.to(device)

model4 = models.efficientnet_b6(pretrained=True)
num_ftrs4 = model4.classifier[1].in_features
model4.classifier[1] = nn.Linear(num_ftrs4, num_class)
checkpoint4 = torch.load(checkpoint4_path) # for effnetb6, imbalance
model4.load_state_dict(checkpoint4['model_state_dict'])
model4 = model4.to(device)
'''
model5 = models.efficientnet_b3(pretrained=True)
num_ftrs5 = model5.classifier[1].in_features
model5.classifier[1] = nn.Linear(num_ftrs5, num_class)
checkpoint5 = torch.load(checkpoint5_path) # for effnetb3 imbalance one more epoch, no imbalance
model5.load_state_dict(checkpoint5['model_state_dict'])
model5 = model5.to(device)

'''
#model1.eval()
model2.eval()
model3.eval()
model4.eval()
#model5.eval()


prediction_o = []
test_prob_list = []
Train1_prob_list = []
Train2_prob_list = []
Train3_prob_list = []
Train4_prob_list = []
Train5_prob_list = []
Train6_prob_list = []
Train7_prob_list = []
Train8_prob_list = []
Train9_prob_list = []
Train10_prob_list = []
with torch.no_grad():
    for batchs in tqdm(test_loader):
        data,_,_ = batchs
        #test_pred1 = model1(data.to(device))
        test_pred2 = model2(data.to(device))
        test_pred3 = model3(data.to(device))
        test_pred4 = model4(data.to(device))
        #test_pred5 = model5(data.to(device))
        test_pred = lam2*test_pred2+lam3*test_pred3+lam4*test_pred4 # Tensor
        test_prob_list.append(test_pred.cpu().data.numpy())
    for batchs in tqdm(Train1_test_loader):
        data,_,_ = batchs
        #Train1_test_pred1 = model1(data.to(device))
        Train1_test_pred2 = model2(data.to(device))
        Train1_test_pred3 = model3(data.to(device))
        Train1_test_pred4 = model4(data.to(device))
        #Train1_test_pred5 = model5(data.to(device))
        Train1_test_pred = lam2*Train1_test_pred2+lam3*Train1_test_pred3+lam4*Train1_test_pred4
                    # Tensor
        Train1_prob_list.append(Train1_test_pred.cpu().data.numpy())
    for batchs in tqdm(Train2_test_loader):
        data,_,_ = batchs
        #Train2_test_pred1 = model1(data.to(device))
        Train2_test_pred2 = model2(data.to(device))
        Train2_test_pred3 = model3(data.to(device))
        Train2_test_pred4 = model4(data.to(device))
        #Train2_test_pred5 = model5(data.to(device))
        Train2_test_pred = lam2*Train2_test_pred2+lam3*Train2_test_pred3+lam4*Train2_test_pred4                   
        Train2_prob_list.append(Train2_test_pred.cpu().data.numpy())
    for batchs in tqdm(Train3_test_loader):
        data,_,_ = batchs
        #Train3_test_pred1 = model1(data.to(device))
        Train3_test_pred2 = model2(data.to(device))
        Train3_test_pred3 = model3(data.to(device))
        Train3_test_pred4 = model4(data.to(device))
        #Train3_test_pred5 = model5(data.to(device))
        Train3_test_pred = lam2*Train3_test_pred2+lam3*Train3_test_pred3+lam4*Train3_test_pred4                  
        Train3_prob_list.append(Train3_test_pred.cpu().data.numpy())
    for batchs in tqdm(Train4_test_loader):
        data,_,_ = batchs
        #Train4_test_pred1 = model1(data.to(device))
        Train4_test_pred2 = model2(data.to(device))
        Train4_test_pred3 = model3(data.to(device))
        Train4_test_pred4 = model4(data.to(device))
        #Train4_test_pred5 = model5(data.to(device))
        Train4_test_pred = lam2*Train4_test_pred2+lam3*Train4_test_pred3+lam4*Train4_test_pred4                  
        Train4_prob_list.append(Train4_test_pred.cpu().data.numpy())
    for batchs in tqdm(Train5_test_loader):
        data,_,_ = batchs
        #Train5_test_pred1 = model1(data.to(device))
        Train5_test_pred2 = model2(data.to(device))
        Train5_test_pred3 = model3(data.to(device))
        Train5_test_pred4 = model4(data.to(device))
        #Train5_test_pred5 = model5(data.to(device))
        Train5_test_pred = lam2*Train5_test_pred2+lam3*Train5_test_pred3+lam4*Train5_test_pred4                  
        Train5_prob_list.append(Train5_test_pred.cpu().data.numpy())
    for batchs in tqdm(Train6_test_loader):
        data,_,_ = batchs
        #Train6_test_pred1 = model1(data.to(device))
        Train6_test_pred2 = model2(data.to(device))
        Train6_test_pred3 = model3(data.to(device))
        Train6_test_pred4 = model4(data.to(device))
        #Train6_test_pred5 = model5(data.to(device))
        Train6_test_pred = lam2*Train6_test_pred2+lam3*Train6_test_pred3+lam4*Train6_test_pred4
                   
        Train6_prob_list.append(Train6_test_pred.cpu().data.numpy())
    for batchs in tqdm(Train7_test_loader):
        data,_,_ = batchs
        #Train7_test_pred1 = model1(data.to(device))
        Train7_test_pred2 = model2(data.to(device))
        Train7_test_pred3 = model3(data.to(device))
        Train7_test_pred4 = model4(data.to(device))
        #Train7_test_pred5 = model5(data.to(device))
        Train7_test_pred = lam2*Train7_test_pred2+lam3*Train7_test_pred3+lam4*Train7_test_pred4                   
        Train7_prob_list.append(Train7_test_pred.cpu().data.numpy())
    '''
    for batchs in tqdm(Train8_test_loader):
        data,_,_ = batchs
        #Train8_test_pred1 = model1(data.to(device))
        Train8_test_pred2 = model2(data.to(device))
        Train8_test_pred3 = model3(data.to(device))
        Train8_test_pred4 = model4(data.to(device))
        #Train8_test_pred5 = model5(data.to(device))
        Train8_test_pred = lam2*Train8_test_pred2+lam3*Train8_test_pred3+lam4*Train8_test_pred4                  
        Train8_prob_list.append(Train8_test_pred.cpu().data.numpy())
    for batchs in tqdm(Train9_test_loader):
        data,_,_ = batchs
        #Train9_test_pred1 = model1(data.to(device))
        Train9_test_pred2 = model2(data.to(device))
        Train9_test_pred3 = model3(data.to(device))
        Train9_test_pred4 = model4(data.to(device))
        #Train9_test_pred5 = model5(data.to(device))
        Train9_test_pred = lam2*Train9_test_pred2+lam3*Train9_test_pred3+lam4*Train9_test_pred4                  
        Train9_prob_list.append(Train9_test_pred.cpu().data.numpy())
    for batchs in tqdm(Train10_test_loader):
        data,_,_ = batchs
        #Train10_test_pred1 = model1(data.to(device))
        Train10_test_pred2 = model2(data.to(device))
        Train10_test_pred3 = model3(data.to(device))
        Train10_test_pred4 = model4(data.to(device))
        #Train10_test_pred5 = model5(data.to(device))
        Train10_test_pred = lam2*Train10_test_pred2+lam3*Train10_test_pred3+lam4*Train10_test_pred4                  
        Train10_prob_list.append(Train10_test_pred.cpu().data.numpy())
    '''
    prob_tot = []
    for i in range(len(test_prob_list)):
      prob_tot.append(w_test*test_prob_list[i] + w_train1*Train1_prob_list[i] + w_train2*Train2_prob_list[i] +\
              w_train3*Train3_prob_list[i] + w_train4*Train4_prob_list[i] + w_train5*Train5_prob_list[i]+\
              w_train6*Train6_prob_list[i]+ w_train7*Train7_prob_list[i])

    test_label = []
    for i in range(len(prob_tot)):
      AA = np.argmax(prob_tot[i], axis=1)
      AA = AA.squeeze()
      test_label.append(AA)
    prediction_o = test_label
    
final_prediction_o = []
for i in prediction_o:
  final_prediction_o+=i.tolist()
print(len(final_prediction_o))
print(final_prediction_o)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b3_rwightman-cf984f9c.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b3_rwightman-cf984f9c.pth
#   0%|          | 0.00/47.2M [00:00<?, ?B/s]
# Downloading: "https://download.pytorch.org/models/efficientnet_b4_rwightman-7eb33cd5.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b4_rwightman-7eb33cd5.pth
#   0%|          | 0.00/74.5M [00:00<?, ?B/s]
# Downloading: "https://download.pytorch.org/models/efficientnet_b6_lukemelas-c76e70fd.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b6_lukemelas-c76e70fd.pth
#   0%|          | 0.00/165M [00:00<?, ?B/s]
# ...
#   0%|          | 0/1250 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f1f7b1a2f80>
# Traceback (most recent call last):
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f1f7b1a2f80>
# ...

# %% [markdown]
# # **Make Predictions**
# ####label = 0 -> banana
# ####label = 1 -> bareland
# ####label = 2 -> carrot
# ####label = 3 -> corn
# ####label = 4 -> dragonfruit
# ####label = 5 -> garlic
# ####label = 6 -> guava
# ####label = 7 -> peanut
# ####label = 8 -> pineapple
# ####label = 9 -> pumpkin
# ####label = 10 -> rice
# ####label = 11 -> soybean
# ####label = 12 -> sugarcane
# ####label = 13 -> tomato

# %%
def write_csv(start, end, name, testset_con=testset_con, prediction_o=final_prediction_o):
  Id_str = []
  for i in range(start,end):
      _,_,C = testset_con.__getitem__(i)
      Id_str.append(C.split("/")[-1])
      #print(Id_str)

  df_o = pd.DataFrame()
  df_o["image_filename"] = Id_str

  string_list = []
  for i in range(start,end):
      if prediction_o[i]==0 :
          string_list.append("banana")
      elif prediction_o[i]==1:
          string_list.append("bareland")
      elif prediction_o[i]==2:
          string_list.append("carrot")
      elif prediction_o[i]==3:
          string_list.append("corn")
      elif prediction_o[i]==4:
          string_list.append("dragonfruit")
      elif prediction_o[i]==5:
          string_list.append("garlic")
      elif prediction_o[i]==6:
          string_list.append("guava")
      elif prediction_o[i]==7:
          string_list.append("peanut")
      elif prediction_o[i]==8:
          string_list.append("pineapple")
      elif prediction_o[i]==9:
          string_list.append("pumpkin")
      elif prediction_o[i]==10:
          string_list.append("rice")
      elif prediction_o[i]==11:
          string_list.append("soybean")
      elif prediction_o[i]==12:
          string_list.append("sugarcane")
      else:
          string_list.append("tomato")

  df_o["label"] = string_list
  df_o.to_csv("submission_"+name+".csv",index = False)

write_csv(0, len(testset_con),"TEAM_645")
